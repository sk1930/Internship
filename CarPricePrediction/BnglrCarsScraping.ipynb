# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains

import numpy as np

# %%
from selenium.common.exceptions import NoSuchElementException

# %%
from selenium.webdriver.chrome.options import Options

option = Options()

option.add_argument("--disable-infobars")
option.add_argument("start-maximized")
option.add_argument("--disable-extensions")

# Pass the argument 1 to allow and 2 to block
option.add_experimental_option("prefs", { 
    "profile.default_content_setting_values.notifications": 2 
})

# %%
driver=webdriver.Chrome(r"E:\softwares\chromedriver.exe",options=option)

# %%
def scroll_to_end(wd):
    wd.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
driver.get("https://www.cardekho.com/used-cars+in+bangalore")
driver.implicitly_wait(3)

# %%
search_btn=driver.find_element_by_xpath("//input[@id='sortbyName']")
search_btn.click()

# %%
search_btn=driver.find_element_by_xpath("//li[@data-value='Price - Low to High']")
search_btn.click()
divContainers=driver.find_elements_by_xpath("//div[@data-card='UCCCarCard']")

# %%
len(divContainers)
# Out:
# 11

# %%
import time

# %%
driver.implicitly_wait(3)

scroll_to_end(driver)

divContainers=driver.find_elements_by_xpath("//div[@data-card='UCCCarCard']")
carLens=len(divContainers)

maxCars=1700
x=1300
z=x
k=0
while carLens < maxCars:
    #scroll_to_end(driver)
    x=x+z
    #driver.execute_script("window.scrollTo(0,Math.max(document.documentElement.scrollHeight,document.body.scrollHeight,document.documentElement.clientHeight))")
    y='window.scrollTo(0,{})'.format(x)
    driver.execute_script(y)
    #scroll_to_end(driver)

    time.sleep(2)
    #driver.implicitly_wait(3)

    divContainers=driver.find_elements_by_xpath("//div[@data-card='UCCCarCard']")
    carLens=len(divContainers)

    print(carLens)

# %%
len(divContainers)
# Out:
# 1744

# %%
driver2=webdriver.Chrome(r"E:\softwares\chromedriver.exe",options=option)

# %%
def getCarDetails(driver2,atag):
    flag=1
    driver2.get(atag)   
    #scroll_to_end(driver2)
    driver2.implicitly_wait(1)
    dictSpecs=dict()
    year=' '
    kms=' '
    owner=' '
    vehicleType=' '
    manual=' '
    location=' '
    amount=' '
    brandName=' '
    try:
        name=driver2.find_element_by_xpath(".//div[@class='vdp-head']/h1[2]").text
        brandName=name.split()[0]

        location='Bangalore'
        amount=driver2.find_element_by_xpath(".//span[@class='amount']").text
        #data-read-more="1"
        try:
            GenDetailsCon=driver2.find_element_by_xpath(".//div[@class='GenDetailBox']")
            liItems=GenDetailsCon.find_elements_by_xpath(".//li[@class='gsc_col-xs-6']")
            year=liItems[0].find_element_by_xpath(".//div/div").text
            kms=liItems[2].find_element_by_xpath(".//div/div").text
            owner=liItems[3].find_element_by_xpath(".//div/div").text
            vehicleType=liItems[4].find_element_by_xpath(".//div/div").text
            manual=liItems[5].find_element_by_xpath(".//div/div").text


        except NoSuchElementException:
            year=''
            kms=''
            owner=''
            vehicleType=''
            manual=''

        
        try:
            search_btn=driver2.find_element_by_xpath("//a[@class=' viewMorebtn viewMorebtnArrow']")
            search_btn.click()
            specs=driver2.find_element_by_xpath(".//div[@class='usedSpecFeatureBoxs ']")

            liItems=specs.find_elements_by_xpath(".//li[@class='gsc_col-xs-6']")
            for liItem in liItems:
                typeItem=liItem.find_element_by_xpath(".//div[@class='smallSpec']").text
                typeVal=liItem.find_element_by_xpath(".//div[@class='largeSpec']").text
                dictSpecs[typeItem]=typeVal
        except:
            pass
    except:
        flag=0
    
    return(flag,year,kms,owner,vehicleType,manual,location,amount,brandName,dictSpecs)

# %%
yearLst=[]
kmsLst=[]
ownerLst=[]
vehicleTypeLst=[]
manualLst=[]
locationLst=[]
amountLst=[]
brandNameLst=[]

mileageLst=[]
engineLst=[]
maxPowerLst=[]
maxPowerRpmLst=[]
seatsLst=[]
ColorLst=[]
GearBoxLst=[]
driveTypeLst=[]
steeringTypeLst=[]
FrontBrkTypeLst=[]
RearBrkTypeLst=[]
TopSpeedLst=[]
accelarationLst=[]
DoorsLst=[]
maxTorqueLst=[]
maxTorqueRpmLst=[]
no_CylindersLst=[]
ValvesCylinderLst=[]
valveConfigLst=[]
fuelSupplyLst=[]



for divContainer in divContainers:
    atag= divContainer.find_element_by_xpath(".//div[@class='gsc_col-xs-7  carsName']/a").get_attribute('href')
    (flag,year,kms,owner,vehicleType,manual,location,amount,brandName,dictSpecs)=getCarDetails(driver2,atag)
    
    
    if flag==1:
        yearLst.append(year)
        kmsLst.append(kms)
        ownerLst.append(owner)
        vehicleTypeLst.append(vehicleType)
        manualLst.append(manual)
        locationLst.append(location)
        amountLst.append(amount)
        brandNameLst.append(brandName)



        mileageLst.append(dictSpecs.get('Mileage',''))
        engineLst.append(dictSpecs.get('Engine',''))
        maxpowerRPM=dictSpecs.get('Max Power','')
        maxpower=''
        maxpowerRpm=''
        try:
            maxpower=maxpowerRPM.split('@')[0]
            maxpowerRpm=maxpowerRPM.split('@')[1]
            maxPowerLst.append(maxpower)
            maxPowerRpmLst.append(maxpowerRpm)
        except:
            maxPowerLst.append(maxpower)
            maxPowerRpmLst.append(maxpowerRpm)
        seatsLst.append(dictSpecs.get('Seats',''))
        ColorLst.append(dictSpecs.get('Color',''))
        GearBoxLst.append(dictSpecs.get('Gear Box',''))
        driveTypeLst.append(dictSpecs.get('Drive Type',''))
        steeringTypeLst.append(dictSpecs.get('Steering Type',''))
        FrontBrkTypeLst.append(dictSpecs.get('Front Brake Type',''))
        RearBrkTypeLst.append(dictSpecs.get('Rear Brake Type',''))
        TopSpeedLst.append(dictSpecs.get('Top Speed',''))
        accelarationLst.append(dictSpecs.get('Acceleration',''))
        DoorsLst.append(dictSpecs.get('No Of Doors',''))




        maxTorqueRPM=maxTorqueLst.append(dictSpecs.get('Max Torque',''))
        maxTorque=''
        maxTorqueRpm=''
        try:
            maxTorque=maxTorqueRPM.split('@')[0]
            maxTorqueRpm=maxTorqueRPM.split('@')[1]
            maxTorqueLst.append(maxTorque)
            maxTorqueRpmLst.append(maxTorqueRpm)
        except:
            maxTorqueLst.append(maxTorque)
            maxTorqueRpmLst.append(maxTorqueRpm)
            
        no_CylindersLst.append(dictSpecs.get('No Of Cylinder',''))
        ValvesCylinderLst.append(dictSpecs.get('Valves Per Cylinder',''))
        valveConfigLst.append(dictSpecs.get('Valve Configuration',''))
        fuelSupplyLst.append(dictSpecs.get('Fuel Supply System',''))

# %%
pd.set_option('display.max_columns',None)

# %%
carsDFBnglr=pd.DataFrame()
carsDFBnglr['year']= yearLst

carsDFBnglr['kms']=kmsLst 
carsDFBnglr['owners']=ownerLst 
carsDFBnglr['vehicle']=vehicleTypeLst 
carsDFBnglr['manual']=manualLst 
carsDFBnglr['location']=locationLst 
carsDFBnglr['amount']=amountLst 
carsDFBnglr['brand']=brandNameLst 

carsDFBnglr['mileage']=mileageLst 
carsDFBnglr['engine']=engineLst 
carsDFBnglr['maxPower']=maxPowerLst 
carsDFBnglr['maxPowerRPM']=maxPowerRpmLst 
carsDFBnglr['seats']=seatsLst 
carsDFBnglr['Color']=ColorLst 
carsDFBnglr['GearBox']=GearBoxLst 
carsDFBnglr['driveType']=driveTypeLst 
carsDFBnglr['SteeringType']=steeringTypeLst 
carsDFBnglr['FrontBrkType']=FrontBrkTypeLst 
carsDFBnglr['RearBrkType']=RearBrkTypeLst 
carsDFBnglr['TopSpeed']=TopSpeedLst 
carsDFBnglr['acceleration']=accelarationLst 

carsDFBnglr['Doors']=DoorsLst
#carsDFBnglr['maxTorque'] =maxTorqueLst
#carsDFBnglr['maxTorqueRPM']=maxTorqueRpmLst
carsDFBnglr['no_cyclinders'] =no_CylindersLst
carsDFBnglr['no_valves'] =ValvesCylinderLst
carsDFBnglr['valveConfig'] =valveConfigLst
carsDFBnglr['fuelSupply'] =fuelSupplyLst




carsDFBnglr['index']=list(range(1,len(brandNameLst)+1))
carsDFBnglr.set_index('index',inplace=True)

carsDFBnglr
# Out:
#        year           kms                owners vehicle     manual   location  \
# index
# 1      2000  1,10,000 kms  Fourth & Above Owner  Petrol  Automatic  Bangalore
# 2      2007    90,000 kms           Third Owner  Petrol     Manual  Bangalore
# 3      2002  1,15,000 kms          Second Owner  Petrol     Manual  Bangalore
# 4      2000    25,000 kms           First Owner  Petrol     Manual  Bangalore
# 5      2004    20,000 kms          Second Owner  Petrol     Manual  Bangalore
# ...     ...           ...                   ...     ...        ...        ...
# 1340   2017    30,435 kms           First Owner  Diesel  Automatic  Bangalore
# 1341   2020    13,000 kms           First Owner  Diesel  Automatic  Bangalore
# 1342   2018    31,450 kms           First Owner  Diesel  Automatic  Bangalore
# 1343   2021     1,000 kms        Test Drive Car  Diesel  Automatic  Bangalore
# 1344   2021     5,300 kms        Test Drive Car  Petrol  Automatic  Bangalore
#
#            amount          brand     mileage   engine    maxPower  \
# index
# 1         48,000*        Hyundai    0.0 kmpl   999 CC        null
# 2         60,000*         Maruti   16.1 kmpl   796 CC       37bhp
# 3         85,000*         Maruti   16.1 kmpl   796 CC       37bhp
# 4         90,000*     Mitsubishi   13.7 kmpl  1468 CC     85.8bhp
# 5      1.05 Lakh*           Ford   14.2 kmpl  1597 CC          92
# ...           ...            ...         ...      ...         ...
# 1340     99 Lakh*       Maserati   12.0 kmpl  2987 CC  270.88 bhp
# 1341      1.2 Cr*  Mercedes-Benz    0.0 kmpl  2925 CC  325.86 bhp
# 1342      1.3 Cr*           Land  13.33 kmpl  2993 CC      255bhp
# 1343      2.5 Cr*  Mercedes-Benz    0.0 kmpl  2925 CC   325.86bhp
# 1344     3.08 Cr*    Lamborghini   7.87 kmpl  3996 CC     641 bhp
#
#         maxPowerRPM seats  Color              GearBox driveType SteeringType  \
# index
# 1                       5                                              Power
# 2           5000rpm     4                     4 Speed       FWD       Manual
# 3           5000rpm     4   Blue              4 Speed       FWD       Manual
# 4           5500rpm     5                     5 Speed       FWD        Power
# 5           5500(PS     5                     5 Speed       FWD
# ...             ...   ...    ...                  ...       ...          ...
# 1340                    5   Blue              8 Speed       AWD
# 1341                    7  White  9G-TRONIC automatic
# 1342        3750rpm     5  White              8 Speed       4WD
# 1343   3600-4200bhp     5  White                            AWD
# 1344                    5    Red                    8       4WD
#
#           FrontBrkType RearBrkType  TopSpeed   acceleration Doors  \
# index
# 1                                                               5
# 2                 Disc        Drum  144km/hr     21 Seconds     4
# 3                 Disc        Drum  144km/hr     21 seconds     4
# 4      Ventilated Disc        Drum  175km/hr  12.95 seconds     4
# 5      Ventilated Disc        Drum  157 kmph   14.5 seconds     4
# ...                ...         ...       ...            ...   ...
# 1340
# 1341
# 1342                          Disc  210 Kmph    8.3 Seconds     5
# 1343
# 1344
#
#       no_cyclinders no_valves valveConfig        fuelSupply
# index
# 1                 4         4        null              null
# 2                 3         2        SOHC              MPFI
# 3                 3         2        SOHC              MPFI
# 4                 4         3        SOHC              MPFI
# 5                 4         2        SOHC              SEFI
# ...             ...       ...         ...               ...
# 1340
# 1341
# 1342              6         4        DOHC  Direct Injection
# 1343              6         0
# 1344
#
# [1344 rows x 26 columns]

# %%
carsDFBnglr.to_csv("cars_Bangalore.csv")

# %%
cars1=pd.read_csv("cars_Bangalore.csv")

# %%
cars1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1344 entries, 0 to 1343
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          1344 non-null   int64
#  1   year           1344 non-null   int64
#  2   kms            1344 non-null   object
#  3   owners         1344 non-null   object
#  4   vehicle        1344 non-null   object
#  5   manual         1344 non-null   object
#  6   location       1344 non-null   object
#  7   amount         1344 non-null   object
#  8   brand          1344 non-null   object
#  9   mileage        1340 non-null   object
#  10  engine         1339 non-null   object
#  11  maxPower       1327 non-null   object
#  12  maxPowerRPM    1010 non-null   object
#  13  seats          1338 non-null   float64
#  14  Color          1273 non-null   object
#  15  GearBox        1324 non-null   object
#  16  driveType      909 non-null    object
#  17  SteeringType   493 non-null    object
#  18  FrontBrkType   719 non-null    object
#  19  RearBrkType    818 non-null    object
#  20  TopSpeed       613 non-null    object
#  21  acceleration   670 non-null    object
#  22  Doors          1017 non-null   float64
#  23  no_cyclinders  1058 non-null   float64
#  24  no_valves      1058 non-null   float64
#  25  valveConfig    900 non-null    object
#  26  fuelSupply     977 non-null    object
# dtypes: float64(4), int64(2), object(21)
# memory usage: 283.6+ KB

# %% [markdown]
# null bhp for maxPower

# %%
# Out:
# Index(['index', 'year', 'kms', 'owners', 'vehicle', 'manual', 'location',
#        'amount', 'brand', 'mileage', 'engine', 'maxPower', 'maxPowerRPM',
#        'seats', 'Color', 'GearBox', 'driveType', 'SteeringType',
#        'FrontBrkType', 'RearBrkType', 'TopSpeed', 'acceleration'],
#       dtype='object')

# %%
cars1.columns



cars1['driveType'].type=str
